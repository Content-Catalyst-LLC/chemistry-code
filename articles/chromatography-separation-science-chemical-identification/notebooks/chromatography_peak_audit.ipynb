# %% [markdown]
# # Chromatography Peak Audit
#
# Synthetic educational notebook scaffold for reproducible chromatography workflows.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
peaks = pd.read_csv(article_dir / 'data' / 'chromatographic_peaks.csv')
library = pd.read_csv(article_dir / 'data' / 'reference_library.csv')
calibration = pd.read_csv(article_dir / 'data' / 'calibration_peak_areas.csv')
peaks.head()

# %% [markdown]
# Synthetic data only. Retention-time matching alone is not definitive chemical identification.
