# %% [markdown]
# # Surface Catalysis Audit
#
# Synthetic educational notebook scaffold for surface chemistry, interfaces, and catalysis.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
catalysts = pd.read_csv(article_dir / 'data' / 'catalyst_candidates.csv')
adsorption = pd.read_csv(article_dir / 'data' / 'adsorption_isotherm.csv')
performance = pd.read_csv(article_dir / 'data' / 'catalyst_performance.csv')
lifecycle = pd.read_csv(article_dir / 'data' / 'lifecycle_notes.csv')
catalysts.head()

# %% [markdown]
# Synthetic data only. Real catalyst evaluation requires validated mechanisms, transport checks, product analysis, stability testing, and safety review.
