# %% [markdown]
# # Environmental Chemistry Workflow
#
# This notebook scaffold supports the article **Environmental Chemistry and the Chemical Conditions of Habitability**. It is intentionally minimal so it can be expanded into a full teaching notebook.

# %%
import math
import pandas as pd
from pathlib import Path

article_dir = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
data = pd.read_csv(article_dir / 'data' / 'environmental_monitoring_synthetic.csv')
data['hazard_quotient'] = data['concentration'] / data['benchmark']
data[['site', 'medium', 'analyte', 'concentration', 'benchmark', 'unit', 'hazard_quotient']]

# %%
c0 = 100.0
k = 0.08
half_life = math.log(2) / k
half_life
