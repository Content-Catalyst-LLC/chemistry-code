# %% [markdown]
# # Colloid Soft Matter Audit
#
# Synthetic educational notebook scaffold for colloids, soft matter, and complex fluids.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
systems = pd.read_csv(article_dir / 'data' / 'colloid_systems.csv')
replicates = pd.read_csv(article_dir / 'data' / 'rheology_replicates.csv')
stability = pd.read_csv(article_dir / 'data' / 'stability_tests.csv')
lifecycle = pd.read_csv(article_dir / 'data' / 'lifecycle_notes.csv')
systems.head()

# %% [markdown]
# Synthetic data only. Real colloid and complex-fluid evaluation requires validated particle-size, stability, rheology, aging, and application-specific testing.
