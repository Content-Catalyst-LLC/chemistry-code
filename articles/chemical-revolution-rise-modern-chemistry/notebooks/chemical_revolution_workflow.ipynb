# %% [markdown]
# # The Chemical Revolution and the Rise of Modern Chemistry
#
# Minimal notebook scaffold for conservation of mass, oxidation, combustion, and nomenclature mapping.

# %% [markdown]
# This notebook uses synthetic educational data. It illustrates quantitative ideas associated with the Chemical Revolution but does not reconstruct actual eighteenth-century experiments.

# %%
from pathlib import Path
import pandas as pd

article_dir = Path('..')
mass = pd.read_csv(article_dir / 'data' / 'mass_conservation_examples.csv')
mass['mass_difference_g'] = mass['product_mass_g'] - mass['reactant_mass_g']
mass

# %% [markdown]
# Interpretation warning: historical chemistry involved instruments, terminology, and assumptions that differed from modern formulas. These examples are teaching scaffolds.
