# %% [markdown]
# # What Is Chemistry?
#
# Minimal notebook scaffold for introductory chemistry calculations.

# %% [markdown]
# This notebook uses synthetic educational data. It is not a laboratory protocol, safety procedure, or validated analytical method.

# %%
from pathlib import Path
import pandas as pd

article_dir = Path('..')
examples = pd.read_csv(article_dir / 'data' / 'intro_chemistry_examples.csv')
examples['moles'] = examples['mass_g'] / examples['molar_mass_g_mol']
examples['molarity_mol_l'] = examples['moles'] / examples['volume_l']
examples

# %% [markdown]
# Interpretation warning: real chemistry requires calibration, uncertainty analysis, validated methods, appropriate equipment, and safety procedures.
