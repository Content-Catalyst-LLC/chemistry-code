# %% [markdown]
# # UV-Vis Calibration Audit
#
# Synthetic educational notebook scaffold for reproducible chemical research.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
runs = pd.read_csv(article_dir / 'data' / 'synthetic_chemical_notebook_runs.csv')
runs.head()

# %% [markdown]
# This notebook should be executed from a clean kernel to avoid hidden-state errors.
