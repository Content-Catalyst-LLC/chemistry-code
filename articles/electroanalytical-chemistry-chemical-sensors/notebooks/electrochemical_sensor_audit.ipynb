# %% [markdown]
# # Electrochemical Sensor Audit
#
# Synthetic educational notebook scaffold for reproducible electroanalytical chemistry workflows.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
calibration = pd.read_csv(article_dir / 'data' / 'sensor_calibration.csv')
unknowns = pd.read_csv(article_dir / 'data' / 'unknown_sensor_samples.csv')
drift = pd.read_csv(article_dir / 'data' / 'sensor_drift.csv')
interferences = pd.read_csv(article_dir / 'data' / 'interference_tests.csv')
calibration.head()

# %% [markdown]
# Synthetic data only. Real electrochemical sensors require selectivity testing, matrix validation, drift evaluation, uncertainty analysis, and reference-method comparison where relevant.
