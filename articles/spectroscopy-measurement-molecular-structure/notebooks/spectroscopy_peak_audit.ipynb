# %% [markdown]
# # Spectroscopy Peak Audit
#
# Synthetic educational notebook scaffold for reproducible spectroscopy workflows.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
ir = pd.read_csv(article_dir / 'data' / 'ir_peaks.csv')
uvvis = pd.read_csv(article_dir / 'data' / 'uvvis_calibration.csv')
nmr = pd.read_csv(article_dir / 'data' / 'nmr_signals.csv')
ir.head()

# %% [markdown]
# Synthetic data only. Real structural assignments require validated methods, reference spectra, instrument metadata, and expert review.
