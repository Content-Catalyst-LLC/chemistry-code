# %% [markdown]
# # Electronic and Photochemical Materials Audit
#
# Synthetic educational notebook scaffold for semiconductor, electronic, and photochemical materials.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
materials = pd.read_csv(article_dir / 'data' / 'material_candidates.csv')
device_runs = pd.read_csv(article_dir / 'data' / 'device_runs.csv')
stability = pd.read_csv(article_dir / 'data' / 'photostability_time_series.csv')
lifecycle = pd.read_csv(article_dir / 'data' / 'lifecycle_notes.csv')
materials.head()

# %% [markdown]
# Synthetic data only. Real device claims require calibrated measurements, defined test conditions, uncertainty, stability testing, and lifecycle review.
