# %% [markdown]
# # Mass Spectrometry Detection Audit
#
# Synthetic educational notebook scaffold for reproducible molecular-detection workflows.

# %%
import pandas as pd
from pathlib import Path

article_dir = Path('..')
features = pd.read_csv(article_dir / 'data' / 'ms_features.csv')
candidates = pd.read_csv(article_dir / 'data' / 'candidate_library.csv')
isotopes = pd.read_csv(article_dir / 'data' / 'isotope_clusters.csv')
fragments = pd.read_csv(article_dir / 'data' / 'msms_fragments.csv')
features.head()

# %% [markdown]
# Synthetic data only. Exact mass alone is not definitive molecular identification.
