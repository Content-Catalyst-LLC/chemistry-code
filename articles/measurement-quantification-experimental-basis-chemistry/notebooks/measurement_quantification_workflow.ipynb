# %% [markdown]
# # Measurement, Quantification, and the Experimental Basis of Chemistry
#
# Minimal notebook scaffold for mass, concentration, calibration, uncertainty, and dilution workflows.

# %% [markdown]
# This notebook uses synthetic educational data. It is not a laboratory protocol, safety procedure, regulatory method, or validated analytical workflow.

# %%
from pathlib import Path
import pandas as pd

article_dir = Path('..')
samples = pd.read_csv(article_dir / 'data' / 'mass_volume_concentration.csv')
samples['moles'] = samples['mass_g'] / samples['molar_mass_g_mol']
samples['concentration_mol_l'] = samples['moles'] / samples['volume_l']
samples

# %% [markdown]
# Interpretation warning: real chemical measurement requires calibration, uncertainty analysis, validated methods, appropriate equipment, trained personnel, and safety procedures.
